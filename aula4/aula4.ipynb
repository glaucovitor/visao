# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido1.png')

qtdeLinhas, qtdeColunas, c = img.shape

B = img[:,:,0]
G = img[:,:,1]
R = img[:,:,2]

W = np.zeros((qtdeLinhas, qtdeColunas, 3), dtype=int) #criando uma imagem toda preta (todos os pixels com valores = 0)


for i in range(qtdeLinhas):
    for j in range(qtdeColunas):
        
        #completar
        
        
plt.imshow(W)

# %% [raw]
# FILTRAGEM MEDIANA

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido2.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape

W = np.zeros((qtdeLinhas, qtdeColunas)) #criando uma imagem toda preta (todos os pixels com valores = 0)

for i in range(1, qtdeLinhas-1):
    for j in range(1, qtdeColunas-1):
        A = img[i-1, j-1]
        B = img[i-1, j]
        C = img[i-1, j+1]
        D = img[i, j+1]
        E = img[i+1, j+1]
        F = img[i+1, j]
        G = img[i+1, j-1]
        H = img[i, j-1]
        Centro = img[i,j]
        W[i,j] = np.median([A,B,C,D,E,F,G,H,Centro])

       
plt.gray()        
plt.imshow(W)

# %% [raw]
# FILTRAGEM MEDIA

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido3.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape

W = np.zeros((qtdeLinhas, qtdeColunas)) #criando uma imagem toda preta (todos os pixels com valores = 0)

for i in range(1, qtdeLinhas-1):
    for j in range(1, qtdeColunas-1):
        A = img[i-1, j-1]
        B = img[i-1, j]
        C = img[i-1, j+1]
        D = img[i, j+1]
        E = img[i+1, j+1]
        F = img[i+1, j]
        G = img[i+1, j-1]
        H = img[i, j-1]
        Centro = img[i,j]
        W[i,j] = np.mean([A,B,C,D,E,F,G,H,Centro])


       
plt.gray()        
plt.imshow(W)

# %% [markdown]
# CONSIDERAR UMA VIZINHANÇA MAIOR

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido3.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape

W = np.zeros((qtdeLinhas, qtdeColunas)) #criando uma imagem toda preta (todos os pixels com valores = 0)

n = 3

for i in range(n, qtdeLinhas-n):
    for j in range(n, qtdeColunas-n):
        Vizinhanca = img[i-n:i+n, j-n:j+n]
        W[i,j] = np.mean(Vizinhanca)

       
plt.gray()        
plt.imshow(W)

# %% [raw]
# FILTRO GAUSSIANO

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido3.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape

W = np.zeros((qtdeLinhas, qtdeColunas)) #criando uma imagem toda preta (todos os pixels com valores = 0)

for i in range(1, qtdeLinhas-1):
    for j in range(1, qtdeColunas-1):
        A = img[i-1, j-1]
        B = 2*img[i-1, j]
        C = img[i-1, j+1]
        D = 2*img[i, j+1]
        E = img[i+1, j+1]
        F = 2*img[i+1, j]
        G = img[i+1, j-1]
        H = 2*img[i, j-1]
        Centro = 4*img[i,j]
     
        W[i,j] = np.mean([A,B,C,D,E,F,G,H,Centro])



       
plt.gray()        
plt.imshow(W)

# %% [raw]
# COMBINAR OS DOIS MÉTODOS DE FILTRAGEM

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido3.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape

W = np.zeros((qtdeLinhas, qtdeColunas)) #criando uma imagem toda preta (todos os pixels com valores = 0)

for i in range(1, qtdeLinhas-1):
    for j in range(1, qtdeColunas-1):
        A = img[i-1, j-1]
        B = img[i-1, j]
        C = img[i-1, j+1]
        D = img[i, j+1]
        E = img[i+1, j+1]
        F = img[i+1, j]
        G = img[i+1, j-1]
        H = img[i, j-1]
        Centro = img[i,j]
        W[i,j] = np.mean([A,B,C,D,E,F,G,H,Centro])


for i in range(1, qtdeLinhas-1):
    for j in range(1, qtdeColunas-1):
        A = W[i-1, j-1]
        B = W[i-1, j]
        C = W[i-1, j+1]
        D = W[i, j+1]
        E = W[i+1, j+1]
        F = W[i+1, j]
        G = W[i+1, j-1]
        H = W[i, j-1]
        Centro = W[i,j]
        W[i,j] = np.mean([A,B,C,D,E,F,G,H,Centro])        
        
        
        
       
plt.gray()        
plt.imshow(W)

# %% [raw]
# APLICAR MAIS DE UMA VEZ O MESMO FILTRO

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido3.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape

W = np.zeros((qtdeLinhas, qtdeColunas)) #criando uma imagem toda preta (todos os pixels com valores = 0)


for k in range(6):
    print('interacao: ', k)
    for i in range(1, qtdeLinhas-1):
        for j in range(1, qtdeColunas-1):
            A = img[i-1, j-1]
            B = img[i-1, j]
            C = img[i-1, j+1]
            D = img[i, j+1]
            E = img[i+1, j+1]
            F = img[i+1, j]
            G = img[i+1, j-1]
            H = img[i, j-1]
            Centro = img[i,j]
            W[i,j] = np.mean([A,B,C,D,E,F,G,H,Centro])
    img = W
    plt.show()        
    plt.imshow(W)
# Out:
# interacao:  0
# interacao:  1
# interacao:  2
# interacao:  3
# interacao:  4
# interacao:  5

# %% [markdown]
# FILTRAGEM ANISOTRÓPICA USANDO EQUAÇÕES DIFERENCIAIS PARCIAIS (EDP)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena.jpg', 0)

img = reduzir_imagem(img, 2)

qtdeLinhas, qtdeColunas = img.shape

W = np.zeros((qtdeLinhas, qtdeColunas)) #criando uma imagem toda preta (todos os pixels com valores = 0)

for i in range(1, qtdeLinhas-1):
    for j in range(1, qtdeColunas-1):
        
        dx = img[i+1,j]-img[i,j]
        dy = img[i,j+1]-img[i,j]
        
        dxx = img[i+1,j]-2*img[i,j]+img[i-1,j]
        dyy = img[i,j+1]-2*img[i,j]+img[i,j-1]
        
        dxy = img[i+1,j+1]-img[i+1,j-1]-img[i-1,j+1]+img[i-1,j-1]
        
        #dx = (img[i+1,j]-img[i-1,j])/2.0 # derivada centrada no eixo x (linhas)
        #dy = (img[i,j+1]-img[i,j-1])/2.0 # derivada centrada no eixo y (colunas)
        
        W[i,j] = dxx
        



       
plt.gray()        
plt.imshow(W)
# Out:
# C:\Users\Glauco\Anaconda\lib\site-packages\ipykernel_launcher.py:18: RuntimeWarning: overflow encountered in ubyte_scalars
# C:\Users\Glauco\Anaconda\lib\site-packages\ipykernel_launcher.py:23: RuntimeWarning: overflow encountered in ubyte_scalars
# C:\Users\Glauco\Anaconda\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in ubyte_scalars

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido3.jpg', 0)

W = img

qtdeLinhas, qtdeColunas = img.shape

h = 0.25

for k in range(5):
    print('interacao: ', k)
    for i in range(1, qtdeLinhas-1):
        for j in range(1, qtdeColunas-1):
            
            dx = img[i+1,j]-img[i,j]
            dy = img[i,j+1]-img[i,j]
        
            dxx = img[i+1,j]-2*img[i,j]+img[i-1,j]
            dyy = img[i,j+1]-2*img[i,j]+img[i,j-1]
        
            dxy = (img[i+1,j+1]-img[i+1,j-1]-img[i-1,j+1]+img[i-1,j-1])/4.0
        
            #dx = (img[i+1,j]-img[i-1,j])/2.0 # derivada centrada no eixo x (linhas)
            #dy = (img[i,j+1]-img[i,j-1])/2.0 # derivada centrada no eixo y (colunas)
        
            calor = dxx+dyy
            
            W[i,j] = img[i,j] + h * calor
    
    img = W



       
plt.gray()        
plt.imshow(img)
# Out:
# 0
# C:\Users\Glauco\Anaconda\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in ubyte_scalars
# C:\Users\Glauco\Anaconda\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in ubyte_scalars
# C:\Users\Glauco\Anaconda\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: overflow encountered in ubyte_scalars
# 1
# 2
# 3
# 4

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


img = cv2.imread('lena_ruido3.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape

h = 0.9

W = img

for k in range(5):
    print('interacao: ', k)
    for i in range(2, qtdeLinhas-2):
        for j in range(2, qtdeColunas-2):
            
            dx = (img[i+1,j]-img[i-1,j])/2.0 # derivada centrada no eixo x (linhas)
            dy = (img[i,j+1]-img[i,j-1])/2.0 # derivada centrada no eixo y (colunas)
            
            
            dxx = (img[i+1,j]-2*img[i,j]+img[i-1,j])/2.0 # derivada segunda centrada
            dyy = (img[i,j+1]-2*img[i,j]+img[i,j-1])/2.0 #derivada segunda centrada
        
            dxy = (dxx+dyy)/4.0
        
            difusao = ((dx**2)*dyy-2*dx*dy*dxy+(dy**2)*dxx)/((dx**2+dy**2)+0.000000001)
            
            W[i,j] = img[i,j] + h * difusao
        
    img = W


       
plt.gray()        
plt.imshow(img)
# Out:
# 0
# C:\Users\Glauco\Anaconda\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning: overflow encountered in ubyte_scalars
# C:\Users\Glauco\Anaconda\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning: overflow encountered in ubyte_scalars
# 1
# 2
# 3
# 4

# %% [markdown]
# CONVOLUÇÃO! Veja o site: http://setosa.io/ev/image-kernels/

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def conv(img, kernel):
    
    kernel_qtdeLinhas, kernel_qtdeColunas = kernel.shape
    
    img_qtdeLinhas, img_qtdeColunas = img.shape
    
    k1 = round(kernel_qtdeLinhas/2)
    k2 = round(kernel_qtdeColunas/2)
    
    
    W = np.zeros((img_qtdeLinhas, img_qtdeColunas))
    
    for i in range(k1, img_qtdeLinhas-k1):
        for j in range(k2, img_qtdeColunas-k2):
            soma = 0
            
            for x in range(kernel_qtdeLinhas):
                for y in range(kernel_qtdeColunas):
                    soma = soma + kernel[x,y]*img[(i-k1)+x, (j-k2)+y]
             
            W[i,j] = soma

    return W




img = cv2.imread('lena.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape


#kernel = np.array([[0,1,0],[1,-4,1],[0,1,0]])
kernel = np.array([[1/16,1/8,1/16],[1/8,1/4,1/8],[1/16,1/8,1/16]])

W = conv(img, kernel)


       
plt.gray()        
plt.imshow(W)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def conv(img, kernel):
    
    kernel_qtdeLinhas, kernel_qtdeColunas = kernel.shape
    
    img_qtdeLinhas, img_qtdeColunas = img.shape
    
    k1 = round(kernel_qtdeLinhas/2)
    k2 = round(kernel_qtdeColunas/2)
    
    
    W = np.zeros((img_qtdeLinhas, img_qtdeColunas))
    
    for i in range(k1, img_qtdeLinhas-k1):
        for j in range(k2, img_qtdeColunas-k2):
            soma = 0
            
            for x in range(kernel_qtdeLinhas):
                for y in range(kernel_qtdeColunas):
                    soma = soma + kernel[x,y]*img[(i-k1)+x, (j-k2)+y]
             
            W[i,j] = soma

    return W




img = cv2.imread('lena.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape


kernel_x = np.array([[0, 0, 0],[1, 0, -1],[0, 0, 0]]) #kernel da derivada em relação a x
kernel_y = np.array([[0, 1, 0],[0, 0, 0],[0, -1, 0]]) #kernel da derivada em relação a y

kernel_xx = np.array([[0, 0, 0],[1, -2, 1],[0, 0, 0]]) #kernel da derivada segunda em relação a x
kernel_yy = np.array([[0, 1, 0],[0, -2, 0],[0, 1, 0]]) #kernel da derivada segunda em relação a y

kernel_xy = kernel_xx+kernel_yy


Wx = conv(img, kernel_x)
Wy = conv(img, kernel_y)
Wxx = conv(img, kernel_xx)
Wyy = conv(img, kernel_yy)
Wxy = conv(img, kernel_xy)

plt.gray()        
plt.imshow(Wx)           
plt.show()        
plt.imshow(Wy)
plt.show()
plt.imshow(Wxx)           
plt.show()        
plt.imshow(Wyy)
plt.show()        
plt.imshow(Wxy)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def conv(img, kernel):
    
    kernel_qtdeLinhas, kernel_qtdeColunas = kernel.shape
    
    img_qtdeLinhas, img_qtdeColunas = img.shape
    
    k1 = round(kernel_qtdeLinhas/2)
    k2 = round(kernel_qtdeColunas/2)
    
    
    W = np.zeros((img_qtdeLinhas, img_qtdeColunas))
    
    for i in range(k1, img_qtdeLinhas-k1):
        for j in range(k2, img_qtdeColunas-k2):
            soma = 0
            
            for x in range(kernel_qtdeLinhas):
                for y in range(kernel_qtdeColunas):
                    soma = soma + kernel[x,y]*img[(i-k1)+x, (j-k2)+y]
             
            W[i,j] = soma

    return W




img = cv2.imread('lena.jpg', 0)

qtdeLinhas, qtdeColunas = img.shape


kernel_x = np.array([[0, 0, 0],[1, 0, -1],[0, 0, 0]]) #kernel da derivada em relação a x
kernel_y = np.array([[0, 1, 0],[0, 0, 0],[0, -1, 0]]) #kernel da derivada em relação a y

kernel_xx = np.array([[0, 0, 0],[1, -2, 1],[0, 0, 0]]) #kernel da derivada segunda em relação a x
kernel_yy = np.array([[0, 1, 0],[0, -2, 0],[0, 1, 0]]) #kernel da derivada segunda em relação a y

kernel_xy = kernel_xx+kernel_yy




for k in range(2):
    print('interacao: ', k)
    #Wx = conv(img, kernel_x)
    #Wy = conv(img, kernel_y)
    Wxx = conv(img, kernel_xx)
    Wyy = conv(img, kernel_yy)
    #Wxy = conv(img, kernel_xy)
    
    img = img + 0.25*(Wxx+Wyy)

plt.gray()        
plt.imshow(img)
# Out:
# interacao:  0
# interacao:  1
